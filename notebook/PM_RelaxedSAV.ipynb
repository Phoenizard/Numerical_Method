# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import wandb

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
X_train, Y_train, X_test, Y_test = torch.load('../data/dataset_3_20D.pt')

# 将数据移动到适当的设备
X_train = X_train.to(device)
Y_train = Y_train.to(device)
X_test = X_test.to(device)
Y_test = Y_test.to(device)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# /tmp/ipykernel_10192/3136768161.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   X_train, Y_train, X_test, Y_test = torch.load('../data/dataset_3_20D.pt')
# (torch.Size([80000, 21]),
#  torch.Size([80000]),
#  torch.Size([20000, 21]),
#  torch.Size([20000]))

# %%
# 使用 DataLoader 进行批处理
l = 256
train_dataset = TensorDataset(X_train, Y_train)
train_loader = DataLoader(train_dataset, batch_size=l, shuffle=True)

# 打印第一个批次的大小
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([256, 21]) torch.Size([256])

# %%
D = 20
m = 10000

# %%
class PM_Euler(nn.Module):
    def __init__(self, input, hidden_layer, output):
        super(PM_Euler, self).__init__()
        self.relu = nn.ReLU()
        self.hidden_dim = hidden_layer
        self.W = nn.Parameter(torch.rand(input, hidden_layer, device=device), requires_grad=True)
        # HE初始化
        nn.init.kaiming_normal_(self.W, mode='fan_in', nonlinearity='relu')
        self.a = nn.Parameter(torch.rand(hidden_layer, output, device=device), requires_grad=True)
        nn.init.kaiming_normal_(self.a, mode='fan_in', nonlinearity='relu')
        
    def forward(self, x):
        # print(x.shape)
        z1 = self.relu(torch.mm(x, self.W))
        # print(z1.shape)
        z2 = torch.mm(z1, self.a) / self.hidden_dim
        return z2

    def loss(self, y_pred, y_true):
        return (y_pred - y_true.reshape(y_pred.shape)) ** 2
model = PM_Euler(D + 1, m, 1).to(device)

# 计算模型W和a的Norm
def get_norm(model):
    return torch.norm(model.W).item(), torch.norm(model.a).item()

get_norm(model)
# Out:
# (6.485015392303467, 141.00892639160156)

# %%
epochs = 10000
lr = 1
C = 100
_lambda = 4
# Define the relax parameters 
r_wave = 0
r_hat = 0
r = 0
a = 0
b = 0
c = 0
ellipsis_0 = 0
ratio_n = 0.99

train_losses = []
test_losses = []

# %%
config = {
    'learning_rate': lr,
    'batch_size': l,
    'epochs': epochs,
    'hidden_layer': m,
    'input': D + 1,
    'output': 1,
    'optimizer': 'RelaxedSAV',
    'C': C,
    '_lambda': _lambda,
    'ratio_n': 0.99,
    'dataset': 'dataset_3_20D'
}

# %%
import datetime

date = datetime.datetime.now().strftime("%m%d%H%M")
wandb.init(project='Numerical Method', name=f"PM_RelaxedSAV_Example_3_{date}", config=config, notes="first try for example 3")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.17.6
# Run data is saved locally in <code>/root/Workspace/Numerical_Method/notebook/wandb/run-20240815_204424-v5r10jrw</code>
# Syncing run <strong><a href='https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method/runs/v5r10jrw' target="_blank">PM_RelaxedSAV_Example_3_08152044</a></strong> to <a href='https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method' target="_blank">https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method</a>
#  View run at <a href='https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method/runs/v5r10jrw' target="_blank">https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method/runs/v5r10jrw</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/pheonizard-university-of-nottingham/Numerical%20Method/runs/v5r10jrw?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
for epoch in range(epochs):
    cnt = 0
    for X, Y in train_loader:
        y_pred = model(X)
        loss = model.loss(y_pred, Y).mean()
        if cnt == 0:
            with torch.no_grad():
                r = torch.sqrt(loss + C)
                cnt = 1
        loss.backward()
        with torch.no_grad():
            #===============Update the parameters in SAV================
            theta_a_1 = model.a.clone()
            theta_w_1 = model.W.clone()
            N_a = model.a.grad.clone()
            N_w = model.W.grad.clone()
            theta_a_2 = -lr * N_a / (torch.sqrt(loss + C) * (1 + lr * _lambda))
            theta_w_2 = -lr * N_w / (torch.sqrt(loss + C) * (1 + lr * _lambda))
            r_wave = r / (1 + lr * (torch.sum(N_a * (N_a / (1 + lr * _lambda))) + torch.sum(N_w * (N_w) / (1 + lr * _lambda))) / (2 * (loss + C)))
            model.a += r_wave.item() * theta_a_2
            model.W += r_wave.item() * theta_w_2
            model.a.grad.zero_()
            model.W.grad.zero_()
            # ===============Update r in SAV================
            tmp_loss = model.loss(model(X), Y).mean()
            r_hat = torch.sqrt(tmp_loss + C)
            a = (r_wave - r_hat) ** 2
            b = 2 * r_hat * (r_wave - r_hat)
            c = r_hat ** 2 - r_wave ** 2 -  ratio_n * (torch.norm(model.a - theta_a_1) ** 2 + torch.norm(model.W - theta_w_1) ** 2) / lr
            if a == 0:
                # 为什么会出现a=0的情况
                print('a == 0')
                ellipsis_0 = 0
            elif (b ** 2 - 4 * a * c) < 0:
                ellipsis_0 = 0
                print('b^2 - 4ac < 0')
            else: 
                ellipsis_0 = max((-b - torch.sqrt(b ** 2 - 4 * a * c)) / (2 * a), 0)
            # print(r, r_wave, r_hat, ellipsis_0, a, b, c, (-b - torch.sqrt(b ** 2 - 4 * a * c)) / (2 * a), r - r_hat)
            r = ellipsis_0 * r_wave + (1 - ellipsis_0) * r_hat
            # 创建log记录变量
            # with open('log.txt', 'a') as f:
            #     f.write(f'epoch {epoch + 1}, loss {loss.item():.6f}, r {r.item():.6f}, r_wave {r_wave.item():.6f}, r_hat {r_hat.item():.6f}, ellipsis_0 {ellipsis_0:.6f},a {a},b {b}, c {c},b^2 - 4ac {b ** 2 - 4 * a * c}\n')
            # 检测是否有nan
            if torch.isnan(r_wave) or torch.isnan(r_hat) or torch.isnan(a) or torch.isnan(b) or torch.isnan(c):
                raise ValueError('nan')
    with torch.no_grad():
        train_loss = model.loss(model(X_train), Y_train).mean()
        test_loss = model.loss(model(X_test), Y_test).mean()
        train_losses.append(train_loss)
        test_losses.append(test_loss)
        norm = get_norm(model)
        wandb.log({'epoch': epoch + 1,
                   'train_loss': train_loss, 
                   'test_loss': test_loss,
                   'norm_W': norm[0],
                   'norm_a': norm[1],
                   'accuracy': 1 - test_loss,
                   'r': r.item(),
                   'r_wave': r_wave.item(),
                   'r_hat': r_hat.item(),
                   'ellipsis': ellipsis_0})
        print(f'epoch {epoch + 1}, loss {train_loss:.6f}, test loss {test_loss:.6f}')
# Out:
# a == 0
# epoch 1, loss 1.009364, test loss 0.961881
# a == 0
# epoch 2, loss 1.009269, test loss 0.961788
# epoch 3, loss 1.009175, test loss 0.961695
# a == 0
# epoch 4, loss 1.009081, test loss 0.961603
# a == 0
# epoch 5, loss 1.008987, test loss 0.961510
# a == 0
# epoch 6, loss 1.008894, test loss 0.961418
# a == 0
# epoch 7, loss 1.008801, test loss 0.961326
# a == 0
# epoch 8, loss 1.008708, test loss 0.961234
# a == 0
# epoch 9, loss 1.008615, test loss 0.961142
# a == 0
# epoch 10, loss 1.008522, test loss 0.961051
# a == 0
# epoch 11, loss 1.008430, test loss 0.960959
# epoch 12, loss 1.008337, test loss 0.960868
# a == 0
# epoch 13, loss 1.008245, test loss 0.960777
# a == 0
# epoch 14, loss 1.008152, test loss 0.960685
# a == 0
# epoch 15, loss 1.008060, test loss 0.960594
# epoch 16, loss 1.007969, test loss 0.960504
# a == 0
# epoch 17, loss 1.007877, test loss 0.960413
# a == 0
# epoch 18, loss 1.007786, test loss 0.960323
# a == 0
# epoch 19, loss 1.007697, test loss 0.960234
# a == 0
# epoch 20, loss 1.007607, test loss 0.960145
# a == 0
# epoch 21, loss 1.007519, test loss 0.960058
# a == 0
# epoch 22, loss 1.007431, test loss 0.959971
# a == 0
# epoch 23, loss 1.007345, test loss 0.959886
# a == 0
# epoch 24, loss 1.007260, test loss 0.959801
# epoch 25, loss 1.007176, test loss 0.959718
# a == 0
# epoch 26, loss 1.007094, test loss 0.959637
# a == 0
# epoch 27, loss 1.007012, test loss 0.959556
# epoch 28, loss 1.006932, test loss 0.959477
# a == 0
# epoch 29, loss 1.006854, test loss 0.959399
# epoch 30, loss 1.006776, test loss 0.959322
# a == 0
# epoch 31, loss 1.006700, test loss 0.959247
# epoch 32, loss 1.006625, test loss 0.959172
# a == 0
# epoch 33, loss 1.006551, test loss 0.959099
# a == 0
# epoch 34, loss 1.006478, test loss 0.959027
# a == 0
# epoch 35, loss 1.006406, test loss 0.958956
# a == 0
# epoch 36, loss 1.006336, test loss 0.958887
# a == 0
# epoch 37, loss 1.006267, test loss 0.958818
# epoch 38, loss 1.006199, test loss 0.958751
# a == 0
# epoch 39, loss 1.006132, test loss 0.958685
# a == 0
# epoch 40, loss 1.006067, test loss 0.958620
# a == 0
# epoch 41, loss 1.006002, test loss 0.958557
# a == 0
# epoch 42, loss 1.005939, test loss 0.958494
# a == 0
# epoch 43, loss 1.005876, test loss 0.958432
# a == 0
# epoch 44, loss 1.005815, test loss 0.958371
# epoch 45, loss 1.005754, test loss 0.958312
# a == 0
# epoch 46, loss 1.005694, test loss 0.958253
# a == 0
# epoch 47, loss 1.005635, test loss 0.958194
# epoch 48, loss 1.005577, test loss 0.958137
# a == 0
# epoch 49, loss 1.005519, test loss 0.958081
# a == 0
# epoch 50, loss 1.005463, test loss 0.958025
# a == 0
# epoch 51, loss 1.005407, test loss 0.957970
# epoch 52, loss 1.005352, test loss 0.957916
# a == 0
# epoch 53, loss 1.005297, test loss 0.957862
# a == 0
# epoch 54, loss 1.005243, test loss 0.957809
# a == 0
# epoch 55, loss 1.005190, test loss 0.957757
# epoch 56, loss 1.005137, test loss 0.957705
# a == 0
# epoch 57, loss 1.005085, test loss 0.957653
# a == 0
# epoch 58, loss 1.005033, test loss 0.957603
# a == 0
# epoch 59, loss 1.004982, test loss 0.957553
# a == 0
# epoch 60, loss 1.004932, test loss 0.957503
# a == 0
# epoch 61, loss 1.004882, test loss 0.957454
# a == 0
# epoch 62, loss 1.004832, test loss 0.957405
# a == 0
# epoch 63, loss 1.004783, test loss 0.957357
# a == 0
# epoch 64, loss 1.004734, test loss 0.957309
# a == 0
# epoch 65, loss 1.004686, test loss 0.957262
# epoch 66, loss 1.004638, test loss 0.957215
# a == 0
# epoch 67, loss 1.004591, test loss 0.957169
# a == 0
# epoch 68, loss 1.004544, test loss 0.957123
# a == 0
# epoch 69, loss 1.004497, test loss 0.957077
# a == 0
# epoch 70, loss 1.004451, test loss 0.957032
# a == 0
# epoch 71, loss 1.004405, test loss 0.956987
# epoch 72, loss 1.004359, test loss 0.956942
# a == 0
# epoch 73, loss 1.004314, test loss 0.956897
# a == 0
# epoch 74, loss 1.004268, test loss 0.956853
# a == 0
# epoch 75, loss 1.004224, test loss 0.956810
# a == 0
# epoch 76, loss 1.004179, test loss 0.956766
# epoch 77, loss 1.004135, test loss 0.956723
# a == 0
# epoch 78, loss 1.004091, test loss 0.956680
# a == 0
# epoch 79, loss 1.004047, test loss 0.956637
# a == 0
# epoch 80, loss 1.004004, test loss 0.956595
# a == 0
# epoch 81, loss 1.003960, test loss 0.956552
# a == 0
# epoch 82, loss 1.003917, test loss 0.956510
# a == 0
# epoch 83, loss 1.003875, test loss 0.956469
# epoch 84, loss 1.003832, test loss 0.956427
# a == 0
# epoch 85, loss 1.003790, test loss 0.956386
# a == 0
# epoch 86, loss 1.003748, test loss 0.956345
# a == 0
# epoch 87, loss 1.003706, test loss 0.956304
# a == 0
# epoch 88, loss 1.003664, test loss 0.956263
# epoch 89, loss 1.003623, test loss 0.956223
# a == 0
# epoch 90, loss 1.003581, test loss 0.956182
# epoch 91, loss 1.003540, test loss 0.956142
# a == 0
# epoch 92, loss 1.003499, test loss 0.956102
# epoch 93, loss 1.003458, test loss 0.956063
# a == 0
# epoch 94, loss 1.003417, test loss 0.956023
# a == 0
# epoch 95, loss 1.003377, test loss 0.955983
# a == 0
# epoch 96, loss 1.003336, test loss 0.955944
# a == 0
# epoch 97, loss 1.003296, test loss 0.955905
# a == 0
# epoch 98, loss 1.003256, test loss 0.955866
# a == 0
# epoch 99, loss 1.003216, test loss 0.955827
# a == 0
# epoch 100, loss 1.003176, test loss 0.955788
# epoch 101, loss 1.003136, test loss 0.955749
# a == 0
# epoch 102, loss 1.003097, test loss 0.955711
# a == 0
# epoch 103, loss 1.003057, test loss 0.955672
# epoch 104, loss 1.003018, test loss 0.955634
# epoch 105, loss 1.002978, test loss 0.955595
# a == 0
# epoch 106, loss 1.002939, test loss 0.955557
# a == 0
# epoch 107, loss 1.002900, test loss 0.955519
# a == 0
# epoch 108, loss 1.002861, test loss 0.955481
# a == 0
# epoch 109, loss 1.002822, test loss 0.955444
# a == 0
# epoch 110, loss 1.002784, test loss 0.955406
# a == 0
# epoch 111, loss 1.002745, test loss 0.955368
# a == 0
# epoch 112, loss 1.002706, test loss 0.955331
# a == 0
# epoch 113, loss 1.002668, test loss 0.955293
# epoch 114, loss 1.002630, test loss 0.955256
# a == 0
# epoch 115, loss 1.002591, test loss 0.955219
# a == 0
# epoch 116, loss 1.002553, test loss 0.955181
# a == 0
# epoch 117, loss 1.002515, test loss 0.955144
# a == 0
# epoch 118, loss 1.002477, test loss 0.955107
# a == 0
# epoch 119, loss 1.002438, test loss 0.955070
# a == 0
# epoch 120, loss 1.002400, test loss 0.955033
# a == 0
# epoch 121, loss 1.002362, test loss 0.954996
# epoch 122, loss 1.002324, test loss 0.954959
# a == 0
# epoch 123, loss 1.002287, test loss 0.954922
# a == 0
# epoch 124, loss 1.002249, test loss 0.954886
# a == 0
# epoch 125, loss 1.002211, test loss 0.954849
# a == 0
# epoch 126, loss 1.002173, test loss 0.954812
# a == 0
# epoch 127, loss 1.002136, test loss 0.954776
# a == 0
# epoch 128, loss 1.002098, test loss 0.954739
# a == 0
# epoch 129, loss 1.002060, test loss 0.954702
# epoch 130, loss 1.002023, test loss 0.954666
# a == 0
# epoch 131, loss 1.001985, test loss 0.954629
# a == 0
# epoch 132, loss 1.001948, test loss 0.954593
# a == 0
# epoch 133, loss 1.001910, test loss 0.954557
# a == 0
# epoch 134, loss 1.001873, test loss 0.954520
# a == 0
# epoch 135, loss 1.001835, test loss 0.954484
# a == 0
# epoch 136, loss 1.001798, test loss 0.954448
# a == 0
# epoch 137, loss 1.001761, test loss 0.954411
# a == 0
# epoch 138, loss 1.001724, test loss 0.954375
# a == 0
# epoch 139, loss 1.001687, test loss 0.954339
# epoch 140, loss 1.001650, test loss 0.954303
# a == 0
# epoch 141, loss 1.001612, test loss 0.954267
# a == 0
# epoch 142, loss 1.001575, test loss 0.954231
# a == 0
# epoch 143, loss 1.001538, test loss 0.954195
# a == 0
# epoch 144, loss 1.001501, test loss 0.954159
# a == 0
# epoch 145, loss 1.001464, test loss 0.954123
# a == 0
# epoch 146, loss 1.001428, test loss 0.954087
# a == 0
# epoch 147, loss 1.001391, test loss 0.954051
# a == 0
# epoch 148, loss 1.001354, test loss 0.954015
# epoch 149, loss 1.001317, test loss 0.953979
# a == 0
# epoch 150, loss 1.001280, test loss 0.953944
# a == 0
# epoch 151, loss 1.001243, test loss 0.953908
# a == 0
# epoch 152, loss 1.001206, test loss 0.953872
# a == 0
# epoch 153, loss 1.001170, test loss 0.953837
# a == 0
# epoch 154, loss 1.001133, test loss 0.953801
# a == 0
# epoch 155, loss 1.001096, test loss 0.953765
# a == 0
# epoch 156, loss 1.001060, test loss 0.953730
# a == 0
# epoch 157, loss 1.001023, test loss 0.953694
# a == 0
# epoch 158, loss 1.000986, test loss 0.953658
# a == 0
# epoch 159, loss 1.000950, test loss 0.953623
# a == 0
# epoch 160, loss 1.000913, test loss 0.953587
# a == 0
# epoch 161, loss 1.000877, test loss 0.953552
# a == 0
# epoch 162, loss 1.000840, test loss 0.953516
# a == 0
# epoch 163, loss 1.000804, test loss 0.953481
# a == 0
# epoch 164, loss 1.000767, test loss 0.953445
# epoch 165, loss 1.000731, test loss 0.953410
# a == 0
# epoch 166, loss 1.000694, test loss 0.953374
# a == 0
# epoch 167, loss 1.000658, test loss 0.953339
# a == 0
# epoch 168, loss 1.000622, test loss 0.953303
# a == 0
# epoch 169, loss 1.000585, test loss 0.953268
# a == 0
# epoch 170, loss 1.000549, test loss 0.953233
# a == 0
# epoch 171, loss 1.000512, test loss 0.953197
# a == 0
# epoch 172, loss 1.000476, test loss 0.953162
# a == 0
# epoch 173, loss 1.000440, test loss 0.953127
# a == 0
# epoch 174, loss 1.000404, test loss 0.953091
# a == 0
# epoch 175, loss 1.000367, test loss 0.953056
# a == 0
# epoch 176, loss 1.000331, test loss 0.953021
# a == 0
# epoch 177, loss 1.000295, test loss 0.952986
# a == 0
# epoch 178, loss 1.000258, test loss 0.952950
# epoch 179, loss 1.000222, test loss 0.952915
# epoch 180, loss 1.000186, test loss 0.952880
# epoch 181, loss 1.000150, test loss 0.952845
# a == 0
# epoch 182, loss 1.000114, test loss 0.952809
# a == 0
# epoch 183, loss 1.000077, test loss 0.952774
# a == 0
# epoch 184, loss 1.000041, test loss 0.952739
# a == 0
# epoch 185, loss 1.000005, test loss 0.952704
# a == 0
# epoch 186, loss 0.999969, test loss 0.952669
# a == 0
# epoch 187, loss 0.999933, test loss 0.952634
# a == 0
# epoch 188, loss 0.999897, test loss 0.952599
# a == 0
# epoch 189, loss 0.999861, test loss 0.952563
# a == 0
# epoch 190, loss 0.999824, test loss 0.952528
# a == 0
# epoch 191, loss 0.999788, test loss 0.952493
# a == 0
# epoch 192, loss 0.999752, test loss 0.952458
# a == 0
# epoch 193, loss 0.999716, test loss 0.952423
# epoch 194, loss 0.999680, test loss 0.952388
# a == 0
# epoch 195, loss 0.999644, test loss 0.952353
# epoch 196, loss 0.999608, test loss 0.952318
# a == 0
# epoch 197, loss 0.999572, test loss 0.952283
# epoch 198, loss 0.999536, test loss 0.952248
# a == 0
# epoch 199, loss 0.999500, test loss 0.952212
# a == 0
# epoch 200, loss 0.999464, test loss 0.952178
# a == 0
# epoch 201, loss 0.999428, test loss 0.952143
# a == 0
# epoch 202, loss 0.999392, test loss 0.952107
# a == 0
# epoch 203, loss 0.999356, test loss 0.952072
# a == 0
# epoch 204, loss 0.999319, test loss 0.952037
# epoch 205, loss 0.999284, test loss 0.952002
# epoch 206, loss 0.999248, test loss 0.951967
# epoch 207, loss 0.999211, test loss 0.951932
# a == 0
# epoch 208, loss 0.999176, test loss 0.951897
# a == 0
# epoch 209, loss 0.999139, test loss 0.951862
# a == 0
# epoch 210, loss 0.999103, test loss 0.951827
# a == 0
# epoch 211, loss 0.999068, test loss 0.951792
# a == 0
# epoch 212, loss 0.999032, test loss 0.951757
# a == 0
# epoch 213, loss 0.998996, test loss 0.951722
# a == 0
# epoch 214, loss 0.998960, test loss 0.951687
# a == 0
# epoch 215, loss 0.998924, test loss 0.951652
# a == 0
# epoch 216, loss 0.998887, test loss 0.951617
# epoch 217, loss 0.998852, test loss 0.951582
# a == 0
# epoch 218, loss 0.998816, test loss 0.951547
# a == 0
# epoch 219, loss 0.998780, test loss 0.951512
# a == 0
# epoch 220, loss 0.998744, test loss 0.951477
# a == 0
# epoch 221, loss 0.998708, test loss 0.951442
# a == 0
# epoch 222, loss 0.998672, test loss 0.951407
# a == 0
# epoch 223, loss 0.998636, test loss 0.951372
# a == 0
# epoch 224, loss 0.998600, test loss 0.951337
# a == 0
# epoch 225, loss 0.998564, test loss 0.951302
# a == 0
# epoch 226, loss 0.998528, test loss 0.951267
# a == 0
# epoch 227, loss 0.998492, test loss 0.951232
# a == 0
# epoch 228, loss 0.998456, test loss 0.951198
# a == 0
# epoch 229, loss 0.998420, test loss 0.951163
# a == 0
# epoch 230, loss 0.998384, test loss 0.951128
# a == 0
# epoch 231, loss 0.998348, test loss 0.951093
# a == 0
# epoch 232, loss 0.998312, test loss 0.951058
# a == 0
# epoch 233, loss 0.998276, test loss 0.951023
# a == 0
# epoch 234, loss 0.998240, test loss 0.950988
# a == 0
# epoch 235, loss 0.998204, test loss 0.950953
# a == 0
# epoch 236, loss 0.998169, test loss 0.950918
# a == 0
# epoch 237, loss 0.998133, test loss 0.950883
# a == 0
# epoch 238, loss 0.998097, test loss 0.950848
# a == 0
# epoch 239, loss 0.998061, test loss 0.950813
# a == 0
# epoch 240, loss 0.998025, test loss 0.950778
# a == 0
# epoch 241, loss 0.997989, test loss 0.950743
# a == 0
# epoch 242, loss 0.997953, test loss 0.950708
# epoch 243, loss 0.997917, test loss 0.950673
# a == 0
# epoch 244, loss 0.997881, test loss 0.950638
# a == 0
# epoch 245, loss 0.997845, test loss 0.950603
# a == 0
# epoch 246, loss 0.997809, test loss 0.950568
# a == 0
# epoch 247, loss 0.997773, test loss 0.950533
# a == 0
# epoch 248, loss 0.997737, test loss 0.950498
# a == 0
# epoch 249, loss 0.997701, test loss 0.950463
# a == 0
# epoch 250, loss 0.997666, test loss 0.950429
# a == 0
# epoch 251, loss 0.997630, test loss 0.950394
# a == 0
# epoch 252, loss 0.997594, test loss 0.950359
# a == 0
# epoch 253, loss 0.997558, test loss 0.950324
# a == 0
# epoch 254, loss 0.997522, test loss 0.950289
# a == 0
# epoch 255, loss 0.997486, test loss 0.950254
# a == 0
# epoch 256, loss 0.997450, test loss 0.950219
# a == 0
# epoch 257, loss 0.997414, test loss 0.950184
# a == 0
# epoch 258, loss 0.997378, test loss 0.950149
# a == 0
# epoch 259, loss 0.997342, test loss 0.950114
# a == 0
# epoch 260, loss 0.997306, test loss 0.950079
# a == 0
# epoch 261, loss 0.997270, test loss 0.950044
# a == 0
# epoch 262, loss 0.997234, test loss 0.950009
# a == 0
# epoch 263, loss 0.997198, test loss 0.949974
# epoch 264, loss 0.997162, test loss 0.949939
# epoch 265, loss 0.997127, test loss 0.949904
# a == 0
# epoch 266, loss 0.997091, test loss 0.949869
# a == 0
# epoch 267, loss 0.997055, test loss 0.949834
# a == 0
# epoch 268, loss 0.997019, test loss 0.949799
# a == 0
# epoch 269, loss 0.996983, test loss 0.949764
# a == 0
# epoch 270, loss 0.996947, test loss 0.949729
# epoch 271, loss 0.996911, test loss 0.949694
# a == 0
# epoch 272, loss 0.996875, test loss 0.949659
# a == 0
# epoch 273, loss 0.996839, test loss 0.949624
# epoch 274, loss 0.996803, test loss 0.949589
# a == 0
# epoch 275, loss 0.996767, test loss 0.949555
# a == 0
# epoch 276, loss 0.996731, test loss 0.949520
# epoch 277, loss 0.996695, test loss 0.949485
# a == 0
# epoch 278, loss 0.996659, test loss 0.949450
# a == 0
# epoch 279, loss 0.996623, test loss 0.949415
# epoch 280, loss 0.996587, test loss 0.949380
# epoch 281, loss 0.996551, test loss 0.949345
# a == 0
# epoch 282, loss 0.996515, test loss 0.949310
# a == 0
# epoch 283, loss 0.996479, test loss 0.949274
# a == 0
# epoch 284, loss 0.996443, test loss 0.949239
# a == 0
# epoch 285, loss 0.996407, test loss 0.949204
# a == 0
# epoch 286, loss 0.996371, test loss 0.949170
# a == 0
# epoch 287, loss 0.996335, test loss 0.949135
# a == 0
# epoch 288, loss 0.996299, test loss 0.949099
# epoch 289, loss 0.996263, test loss 0.949064
# a == 0
# epoch 290, loss 0.996227, test loss 0.949029
# a == 0
# epoch 291, loss 0.996191, test loss 0.948994
# a == 0
# epoch 292, loss 0.996155, test loss 0.948959
# a == 0
# epoch 293, loss 0.996119, test loss 0.948924
# a == 0
# epoch 294, loss 0.996083, test loss 0.948889
# a == 0
# epoch 295, loss 0.996047, test loss 0.948854
# a == 0
# epoch 296, loss 0.996011, test loss 0.948819
# a == 0
# epoch 297, loss 0.995975, test loss 0.948784
# a == 0
# epoch 298, loss 0.995939, test loss 0.948749
# a == 0
# epoch 299, loss 0.995903, test loss 0.948714
# a == 0
# epoch 300, loss 0.995867, test loss 0.948679
# a == 0
# epoch 301, loss 0.995831, test loss 0.948644
# a == 0
# epoch 302, loss 0.995795, test loss 0.948609
# a == 0
# epoch 303, loss 0.995759, test loss 0.948574
# a == 0
# epoch 304, loss 0.995723, test loss 0.948539
# a == 0
# epoch 305, loss 0.995687, test loss 0.948504
# a == 0
# epoch 306, loss 0.995651, test loss 0.948468
# a == 0
# epoch 307, loss 0.995614, test loss 0.948433
# a == 0
# epoch 308, loss 0.995578, test loss 0.948398
# a == 0
# epoch 309, loss 0.995542, test loss 0.948363
# a == 0
# epoch 310, loss 0.995506, test loss 0.948328
# a == 0
# epoch 311, loss 0.995470, test loss 0.948293
# a == 0
# epoch 312, loss 0.995434, test loss 0.948258
# a == 0
# epoch 313, loss 0.995398, test loss 0.948223
# epoch 314, loss 0.995362, test loss 0.948188
# a == 0
# epoch 315, loss 0.995326, test loss 0.948153
# a == 0
# epoch 316, loss 0.995290, test loss 0.948117
# a == 0
# epoch 317, loss 0.995253, test loss 0.948082
# a == 0
# epoch 318, loss 0.995217, test loss 0.948047
# a == 0
# epoch 319, loss 0.995181, test loss 0.948012
# a == 0
# epoch 320, loss 0.995145, test loss 0.947977
# a == 0
# epoch 321, loss 0.995109, test loss 0.947942
# a == 0
# epoch 322, loss 0.995073, test loss 0.947907
# a == 0
# epoch 323, loss 0.995037, test loss 0.947872
# a == 0
# epoch 324, loss 0.995001, test loss 0.947836
# a == 0
# epoch 325, loss 0.994964, test loss 0.947801
# a == 0
# epoch 326, loss 0.994928, test loss 0.947766
# a == 0
# epoch 327, loss 0.994892, test loss 0.947731
# a == 0
# epoch 328, loss 0.994856, test loss 0.947695
# a == 0
# epoch 329, loss 0.994820, test loss 0.947660
# a == 0
# epoch 330, loss 0.994783, test loss 0.947625
# a == 0
# epoch 331, loss 0.994747, test loss 0.947590
# a == 0
# epoch 332, loss 0.994711, test loss 0.947555
# a == 0
# epoch 333, loss 0.994675, test loss 0.947519
# a == 0
# epoch 334, loss 0.994639, test loss 0.947484
# a == 0
# epoch 335, loss 0.994603, test loss 0.947449
# a == 0
# epoch 336, loss 0.994566, test loss 0.947414
# a == 0
# epoch 337, loss 0.994530, test loss 0.947379
# a == 0
# epoch 338, loss 0.994494, test loss 0.947344
# epoch 339, loss 0.994458, test loss 0.947308
# a == 0
# epoch 340, loss 0.994421, test loss 0.947273
# a == 0
# epoch 341, loss 0.994385, test loss 0.947238
# a == 0
# epoch 342, loss 0.994349, test loss 0.947203
# a == 0
# epoch 343, loss 0.994313, test loss 0.947168
# a == 0
# epoch 344, loss 0.994276, test loss 0.947132
# a == 0
# epoch 345, loss 0.994240, test loss 0.947097
# a == 0
# epoch 346, loss 0.994204, test loss 0.947062
# a == 0
# epoch 347, loss 0.994168, test loss 0.947026
# a == 0
# epoch 348, loss 0.994131, test loss 0.946991
# a == 0
# epoch 349, loss 0.994095, test loss 0.946956
# a == 0
# epoch 350, loss 0.994059, test loss 0.946921
# epoch 351, loss 0.994023, test loss 0.946885
# a == 0
# epoch 352, loss 0.993986, test loss 0.946850
# a == 0
# epoch 353, loss 0.993950, test loss 0.946815
# a == 0
# epoch 354, loss 0.993914, test loss 0.946779
# a == 0
# epoch 355, loss 0.993878, test loss 0.946744
# a == 0
# epoch 356, loss 0.993841, test loss 0.946709
# epoch 357, loss 0.993805, test loss 0.946674
# a == 0
# epoch 358, loss 0.993769, test loss 0.946638
# a == 0
# epoch 359, loss 0.993732, test loss 0.946603
# a == 0
# epoch 360, loss 0.993696, test loss 0.946568
# a == 0
# epoch 361, loss 0.993660, test loss 0.946532
# a == 0
# epoch 362, loss 0.993623, test loss 0.946497
# epoch 363, loss 0.993587, test loss 0.946461
# epoch 364, loss 0.993550, test loss 0.946426
# a == 0
# epoch 365, loss 0.993514, test loss 0.946391
# a == 0
# epoch 366, loss 0.993478, test loss 0.946355
# a == 0
# epoch 367, loss 0.993441, test loss 0.946320
# a == 0
# epoch 368, loss 0.993405, test loss 0.946285
# a == 0
# epoch 369, loss 0.993369, test loss 0.946249
# a == 0
# epoch 370, loss 0.993332, test loss 0.946214
# a == 0
# epoch 371, loss 0.993296, test loss 0.946179
# a == 0
# epoch 372, loss 0.993259, test loss 0.946143
# a == 0
# epoch 373, loss 0.993223, test loss 0.946108
# a == 0
# epoch 374, loss 0.993187, test loss 0.946072
# a == 0
# epoch 375, loss 0.993150, test loss 0.946037
# a == 0
# epoch 376, loss 0.993114, test loss 0.946002
# a == 0
# epoch 377, loss 0.993077, test loss 0.945966
# a == 0
# epoch 378, loss 0.993041, test loss 0.945931
# a == 0
# epoch 379, loss 0.993004, test loss 0.945895
# a == 0
# epoch 380, loss 0.992968, test loss 0.945860
# a == 0
# epoch 381, loss 0.992932, test loss 0.945824
# a == 0
# epoch 382, loss 0.992895, test loss 0.945789
# a == 0
# epoch 383, loss 0.992859, test loss 0.945753
# a == 0
# epoch 384, loss 0.992822, test loss 0.945718
# a == 0
# epoch 385, loss 0.992786, test loss 0.945682
# a == 0
# epoch 386, loss 0.992749, test loss 0.945647
# a == 0
# epoch 387, loss 0.992713, test loss 0.945611
# a == 0
# epoch 388, loss 0.992676, test loss 0.945576
# a == 0
# epoch 389, loss 0.992640, test loss 0.945540
# a == 0
# epoch 390, loss 0.992603, test loss 0.945505
# a == 0
# epoch 391, loss 0.992567, test loss 0.945469
# a == 0
# epoch 392, loss 0.992530, test loss 0.945434
# a == 0
# epoch 393, loss 0.992494, test loss 0.945398
# a == 0
# epoch 394, loss 0.992457, test loss 0.945363
# a == 0
# epoch 395, loss 0.992421, test loss 0.945327
# a == 0
# epoch 396, loss 0.992384, test loss 0.945292
# a == 0
# epoch 397, loss 0.992348, test loss 0.945256
# a == 0
# epoch 398, loss 0.992311, test loss 0.945221
# a == 0
# epoch 399, loss 0.992274, test loss 0.945185
# a == 0
# epoch 400, loss 0.992238, test loss 0.945150
# a == 0
# epoch 401, loss 0.992201, test loss 0.945114
# a == 0
# epoch 402, loss 0.992165, test loss 0.945079
# epoch 403, loss 0.992128, test loss 0.945043
# a == 0
# epoch 404, loss 0.992091, test loss 0.945007
# a == 0
# epoch 405, loss 0.992055, test loss 0.944972
# a == 0
# epoch 406, loss 0.992018, test loss 0.944936
# epoch 407, loss 0.991982, test loss 0.944901
# a == 0
# epoch 408, loss 0.991945, test loss 0.944865
# a == 0
# epoch 409, loss 0.991908, test loss 0.944829
# a == 0
# epoch 410, loss 0.991872, test loss 0.944794
# epoch 411, loss 0.991835, test loss 0.944758
# a == 0
# epoch 412, loss 0.991798, test loss 0.944722
# a == 0
# epoch 413, loss 0.991762, test loss 0.944687
# epoch 414, loss 0.991725, test loss 0.944651
# a == 0
# epoch 415, loss 0.991688, test loss 0.944616
# a == 0
# epoch 416, loss 0.991652, test loss 0.944580
# a == 0
# epoch 417, loss 0.991615, test loss 0.944544
# a == 0
# epoch 418, loss 0.991578, test loss 0.944509
# a == 0
# epoch 419, loss 0.991542, test loss 0.944473
# a == 0
# epoch 420, loss 0.991505, test loss 0.944437
# epoch 421, loss 0.991468, test loss 0.944402
# a == 0
# epoch 422, loss 0.991432, test loss 0.944366
# epoch 423, loss 0.991395, test loss 0.944330
# a == 0
# epoch 424, loss 0.991358, test loss 0.944294
# a == 0
# epoch 425, loss 0.991321, test loss 0.944259
# a == 0
# epoch 426, loss 0.991285, test loss 0.944223
# a == 0
# epoch 427, loss 0.991248, test loss 0.944187
# a == 0
# epoch 428, loss 0.991211, test loss 0.944151
# a == 0
# epoch 429, loss 0.991174, test loss 0.944116
# a == 0
# epoch 430, loss 0.991138, test loss 0.944080
# a == 0
# epoch 431, loss 0.991101, test loss 0.944044
# a == 0
# epoch 432, loss 0.991064, test loss 0.944008
# epoch 433, loss 0.991027, test loss 0.943973
# a == 0
# epoch 434, loss 0.990990, test loss 0.943937
# a == 0
# epoch 435, loss 0.990954, test loss 0.943901
# a == 0
# epoch 436, loss 0.990917, test loss 0.943865
# a == 0
# epoch 437, loss 0.990880, test loss 0.943829
# a == 0
# epoch 438, loss 0.990843, test loss 0.943794
# a == 0
# epoch 439, loss 0.990806, test loss 0.943758
# a == 0
# epoch 440, loss 0.990769, test loss 0.943722
# a == 0
# epoch 441, loss 0.990732, test loss 0.943686
# a == 0
# epoch 442, loss 0.990695, test loss 0.943650
# a == 0
# epoch 443, loss 0.990659, test loss 0.943614
# a == 0
# epoch 444, loss 0.990622, test loss 0.943578
# a == 0
# epoch 445, loss 0.990585, test loss 0.943543
# a == 0
# epoch 446, loss 0.990548, test loss 0.943507
# a == 0
# epoch 447, loss 0.990511, test loss 0.943471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 52
#      50 train_losses.append(train_loss)
#      51 test_losses.append(test_loss)
# ---> 52 norm = get_norm(model)
#      53 wandb.log({'epoch': epoch + 1,
#      54            'train_loss': train_loss,
#      55            'test_loss': test_loss,
#    (...)
#      61            'r_hat': r_hat.item(),
#      62            'ellipsis': ellipsis_0})
#      63 print(f'epoch {epoch + 1}, loss {train_loss:.6f}, test loss {test_loss:.6f}')
#
# Cell In[6], line 25, in get_norm(model)
#      24 def get_norm(model):
# ---> 25     return torch.norm(model.W).item(), torch.norm(model.a).item()
#
# KeyboardInterrupt:

# %%
wandb.finish()
